# %% [markdown]
# # JupyterLite E2E smoke test
#
# This notebook is used by the Playwright smoke test.

# %%
# %pip install hscmap

# %%
import hscmap

print('hscmap import ok')
print(hscmap.__file__)
