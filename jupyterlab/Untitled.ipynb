# %%
import stellarglobe.window
import importlib
importlib.reload(stellarglobe.window)
# Out:
# <module 'stellarglobe.window' from '/Users/michitaro/Desktop/codes/stelar-globe/jupyterlab/stellarglobe/window.py'>

# %%
window = stellarglobe.window.Window(title='hello')

# %%
window._post_message({
    'type': 'setState',
    'args': {
        'layerDefs': [
            {'type': 'SspTileLayer', 'key': '4', 'props': {
                'baseUrl': '//hscmap.mtk.nao.ac.jp/hscMap4/data/pdr3_wide',
                # 'baseUrl': '//hscmap.mtk.nao.ac.jp/hscMap4/data/la2016',           
                'outline': True,
                'visible': True,
            }},
            {'type': 'GridLayer', 'key': '1', 'props': {}},
            {'type': 'EsoMilkyWayLayer', 'key': '2', 'props': {}},
            {'type': 'HipparcosCatalogLayer', 'key': '3', 'props': {}},
        ],
    },
})
